# %%
import pandas as pd

file = pd.read_csv("/workspaces/MRKTO_python/data.csv")

df = file.copy()

df
# Out:
#    Company number    Company name   Status  Founded        Country  \
# 0               1          Clever  Private     2012            USA
# 1               2            Ramp  Private     2019             US
# 2               3            Pro1  Private     2017             US
# 3               4          OctoML  Private     2018  United States
# 4               5        Substack  Private     2017            USA
# 5               6  United Masters  Private     2017            USA
# 6               7        Icosavax  Private     2016            USA
# 7               8        Palantir   Public     2003             US
# 8               9        Coursera   Public     2012  United States
# 9              10           Tempo  Private     2015  United States
#
#    Number employees*  VC financed Funding round  Sales agents* Revenue*
# 0                149            1      Series B             58       32
# 1                242            1      Series B             76       42
# ...

# %% [markdown]
# ### Setting Values

# %%
df.loc[df['Funding round'] == '-', 'Funding round'] = 'N/A'
df
# Out:
#    Company number    Company name   Status  Founded        Country  \
# 0               1          Clever  Private     2012            USA
# 1               2            Ramp  Private     2019             US
# 2               3            Pro1  Private     2017             US
# 3               4          OctoML  Private     2018  United States
# 4               5        Substack  Private     2017            USA
# 5               6  United Masters  Private     2017            USA
# 6               7        Icosavax  Private     2016            USA
# 7               8        Palantir   Public     2003             US
# 8               9        Coursera   Public     2012  United States
# 9              10           Tempo  Private     2015  United States
#
#    Number employees*  VC financed Funding round  Sales agents* Revenue*
# 0                149            1      Series B             58       32
# 1                242            1      Series B             76       42
# ...

# %% [markdown]
# ### Filtering using .isin()

# %%
df_isin = df.loc[df['Company name'].isin(['Clever', 'Palantir'])].copy()
df_isin
# Out:
#    Company number Company name   Status  Founded Country  Number employees*  \
# 0               1       Clever  Private     2012     USA                149
# 7               8     Palantir   Public     2003      US               2500
#
#    VC financed Funding round  Sales agents* Revenue*
# 0            1      Series B             58       32
# 7            0        Public            234     1500

# %% [markdown]
# ### Selecting a Subset of Rows and Columns

# %%
df_novo = df_sliced.loc['Private',['Country','Sales agents*']].copy()
df_novo
# Out:
#                Country  Sales agents*
# Status
# Private            USA             58
# Private             US             76
# Private         BRAZIL             32
# Private  United States             12
# Private            USA             43
# Private            USA             12
# Private            USA             18
# Private  United States             24
